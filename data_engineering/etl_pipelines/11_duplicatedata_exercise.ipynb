# %% [markdown]
# # Duplicate Data
#
# A data set might have duplicate data: in other words, the same record is represented multiple times. Sometimes, it's easy to find and eliminate duplicate data like when two records are exactly the same. At other times, like what was discussed in the video, duplicate data is hard to spot.
#
# # Exercise 1
#
# From the World Bank GDP data, count the number of countries that have had a project totalamt greater than 1 billion dollars (1,000,000,000). To get the count, you'll have to remove duplicate data rows.

# %%
import pandas as pd
pd.options.display.max_columns = None


# read in the projects data set and do some basic wrangling 
projects = pd.read_csv('../data/projects_data.csv', dtype=str)
projects.drop('Unnamed: 56', axis=1, inplace=True)
projects['totalamt'] = pd.to_numeric(projects['totalamt'].str.replace(',', ''))
projects['countryname'] = projects['countryname'].str.split(';', expand=True)[0]
projects['boardapprovaldate'] = pd.to_datetime(projects['boardapprovaldate'])

# TODO: filter the data frame for projects over 1 billion dollars
# TODO: count the number of unique countries in the results
projects.loc[projects['totalamt']>1_000_000_000, 'countryname'].nunique()
# Out:
# 17

# %% [markdown]
# # Exercise 2 (challenge)
#
# This exercise is more challenging. The projects data set contains data about Yugoslavia, which was an Eastern European country until 1992. Yugoslavia eventually broke up into 7 countries: Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Montenegro, Serbia, and Slovenia.
#
# But the projects dataset has some ambiguity in how it treats Yugoslavia and the 7 countries that came from Yugoslavia. Your task is to find Yugoslavia projects that are probably represented multiple times in the data set.

# %%
# TODO: output all projects for the 'Socialist Federal Republic of Yugoslavia'
# HINT: You can use the exact country name or use the pandas str.contains() method to search for Yugoslavia
projects.loc[projects['countryname'].str.lower().str.contains('yugoslavia')]
# Out:
#             id               regionname  \
# 11166  P009285  Europe and Central Asia
# 11410  P009231  Europe and Central Asia
# 11479  P009219  Europe and Central Asia
# 11694  P009225  Europe and Central Asia
# 11695  P009275  Europe and Central Asia
# 11866  P009242  Europe and Central Asia
# 12060  P009265  Europe and Central Asia
# 12225  P009217  Europe and Central Asia
# 12227  P038996  Europe and Central Asia
# 12375  P009215  Europe and Central Asia
# 12577  P009212  Europe and Central Asia
# 12617  P009211  Europe and Central Asia
# 12671  P009205  Europe and Central Asia
# 12677  P009214  Europe and Central Asia
# 12809  P009210  Europe and Central Asia
# 13041  P009207  Europe and Central Asia
# 13046  P009206  Europe and Central Asia
# 13047  P009208  Europe and Central Asia
# 13053  P009209  Europe and Central Asia
# 13071  P009203  Europe and Central Asia
# 13098  P009201  Europe and Central Asia
# 13099  P009202  Europe and Central Asia
# 13231  P009204  Europe and Central Asia
# 13365  P009198  Europe and Central Asia
# 13402  P009197  Europe and Central Asia
# 13412  P009199  Europe and Central Asia
# 13526  P009200  Europe and Central Asia
# 13555  P009196  Europe and Central Asia
# 13629  P009193  Europe and Central Asia
# 13647  P009195  Europe and Central Asia
# ...        ...                      ...
# 15136  P009163  Europe and Central Asia
# 15182  P009164  Europe and Central Asia
# 15214  P009156  Europe and Central Asia
# 15238  P009160  Europe and Central Asia
# 15273  P009158  Europe and Central Asia
# 15274  P009159  Europe and Central Asia
# 15314  P009157  Europe and Central Asia
# 15388  P009155  Europe and Central Asia
# 15434  P009154  Europe and Central Asia
# 15563  P009153  Europe and Central Asia
# 17836                Specific Investment Loan               IN
# 17861                Specific Investment Loan               IN
# 17903                Specific Investment Loan               IN
# 17963                Specific Investment Loan               IN
# 18175              Structural Adjustment Loan               AD
# 18197              Structural Adjustment Loan               AD
# 18228                Specific Investment Loan               IN
#
#       envassesmentcategorycode supplementprojectflg productlinetype  \
# 11166                        A                    N               L
# 11410                        B                    N               L
# 11479                        C                    N               L
# 11694                        C                    N               L
# 11695                      NaN                    N               L
# 11866                        C                    N               L
# 12060                        C                    N               L
# 12225                        C                    N               L
# 12227                        C                    Y               L
# 12375                        C                    N               L
# 12577                        C                    N               L
# 12617                      NaN                    N               L
# 12671                      NaN                    N               L
# 12677                      NaN                    N               L
# 12809                      NaN                    N               L
# 13041                      NaN                    N               L
# 13046                      NaN                    N               L
# 13047                        C                    N               L
# 13053                        C                    N               L
# 13071                      NaN                    N               L
# 13098                      NaN                    N               L
# 13099                      NaN                    N               L
# 13231                      NaN                    N               L
# 13365                      NaN                    N               L
# 13402                      NaN                    N               L
# 13412                      NaN                    N               L
# 13526                      NaN                    N               L
# 13555                      NaN                    N               L
# 13629                      NaN                    N               L
# 13647                      NaN                    N               L
# ...                        ...                  ...             ...
# 15136                      NaN                    N               L
# 15182                      NaN                    N               L
# 15214                      NaN                    N               L
# 15238                      NaN                    N               L
# 15273                      NaN                    N               L
# 15274                      NaN                    N               L
# 15314                      NaN                    N               L
# 15388                      NaN                    N               L
# 15434                      NaN                    N               L
# 15563                      NaN                    N               L
# 15683                      NaN                    N               L
# 15684                      NaN                    N               L
# 15694                      NaN                    N               L
# 15695                      NaN                    N               L
# 15835                      NaN                    N               L
# 15879                      NaN                    N               L
# 15885                      NaN                    N               L
# 17467                      NaN                    N               L
# 17540                      NaN                    N               L
# 17576                      NaN                    N               L
# 17612                      NaN                    N               L
# 17638                      NaN                    N               L
# 17774                      NaN                    N               L
# 17836                      NaN                    N               L
# 17861                      NaN                    N               L
# 17903                      NaN                    N               L
# 17963                      NaN                    N               L
# 18175                      NaN                    N               L
# 18197                      NaN                    N               L
# 18228                      NaN                    N               L
#
#       projectstatusdisplay  status  \
# 11166               Closed  Closed
# 11410               Closed  Closed
# 11479               Closed  Closed
# 11694               Closed  Closed
# 11695               Closed  Closed
# 11866               Closed  Closed
# 12060               Closed  Closed
# 12225               Closed  Closed
# 12227               Closed  Closed
# 12375               Closed  Closed
# 12577               Closed  Closed
# 12617               Closed  Closed
# 12671               Closed  Closed
# 12677               Closed  Closed
# 12809               Closed  Closed
# 13041               Closed  Closed
# 13046               Closed  Closed
# 13047               Closed  Closed
# 13053               Closed  Closed
# 13071               Closed  Closed
# 13098               Closed  Closed
# 13099               Closed  Closed
# 13231               Closed  Closed
# 13365               Closed  Closed
# 13402               Closed  Closed
# 13412               Closed  Closed
# 13526               Closed  Closed
# 13555               Closed  Closed
# 13629               Closed  Closed
# 13647               Closed  Closed
# ...                    ...     ...
# 15136               Closed  Closed
# 15182               Closed  Closed
# 15214               Closed  Closed
# 15238               Closed  Closed
# 15273               Closed  Closed
# 15274               Closed  Closed
# 15314               Closed  Closed
# 15388               Closed  Closed
# 15434               Closed  Closed
# 15563               Closed  Closed
# 15683               Closed  Closed
# 15684               Closed  Closed
# 15694               Closed  Closed
# 15695               Closed  Closed
# 15835               Closed  Closed
# 15879               Closed  Closed
# 15885               Closed  Closed
# 17467               Closed  Closed
# 17540               Closed  Closed
# 17576               Closed  Closed
# 17612               Closed  Closed
# 17638               Closed  Closed
# 17774               Closed  Closed
# 17836               Closed  Closed
# 17861               Closed  Closed
# 17903               Closed  Closed
# 17963               Closed  Closed
# 18175               Closed  Closed
# 18197               Closed  Closed
# 18228               Closed  Closed
#
#                                             project_name boardapprovaldate  \
# 11166    Kolubara B Thermal Power & Lignite Mine Project        1991-06-25
# 11410                   Highway Sector Loan Project (03)        1990-06-20
# 11479            Structural Adjustment Loan Project (02)        1990-04-12
# 11694                               Railway Project (07)        1989-05-23
# 11695             Istria Water Supply & Sewerage Project        1989-05-23
# 11866                 Export Oriented Industries Project        1988-06-29
# 12060                        Highway Sector Project (02)        1987-10-13
# 12225         Energy Conservation & Substitution Project        1987-03-31
# 12227                                IND.ENERGY EFFIC. I        1987-03-31
# 12375                             Highway Sector Project        1986-06-10
# 12577                           Petroleum Sector Project        1985-06-27
# 12617                Bosnia Herzegovina Forestry Project        1985-06-06
# 12671                     Fertilizer Sector Loan Project        1985-05-03
# 12677                     Visegrad Hydroelectric Project        1985-04-30
# 12809            Montenegro Regional Development Project        1984-07-31
# 13041                                  MOSTAR POWER(SAP)        1983-08-02
# 13046                     Industrial Credit Project (07)        1983-07-26
# 13047  Power Transmission Project (03) Energy Managem...        1983-07-26
# 13053                               Railway Project (06)        1983-07-19
# 13071            Structural Adjustment Loan Project (01)        1983-06-28
# 13098                Kosovo Regional Development Project        1983-06-09
# 13099                Serbia Regional Development Project        1983-06-09
# 13231    Tuzla Region Water Supply & Environment Project        1983-01-25
# 13365                         Semberija Drainage Project        1982-05-27
# 13402  Bosnia Herzegovina Agriculture Development Pro...        1982-05-04
# 13412                     Industrial Credit Project (06)        1982-04-27
# 13526                        Kosovo Water Supply Project        1981-11-10
# 13555     Macedonia Agriculture Development Project (03)        1981-07-14
# 13629             Kosovo Agriculture Development Project        1981-05-14
# 13647                             Kosovo Railway Project        1981-04-28
# ...                                                  ...               ...
# 15136                                Port of Bar Project        1974-11-26
# 15182                               Railway Project (04)        1974-07-02
# 15214         Industrial Credit Macedonia Kosovo Project        1974-06-06
# 15238                               Highway Project (06)        1974-05-21
# 15273                           FOB Iron Foundry Project        1974-02-19
# 15274                      IMT Tractor Expansion Project        1974-02-19
# 15314                       Kikinda Iron Foundry Project        1973-11-20
# 15388                         Naftagas Pipelines Project        1973-06-19
# 15434                     Agriculture Industries Project        1973-05-15
# 15563                         Power Transmission Project        1972-06-13
# 15683                          Babin Kuk Tourism Project        1971-06-17
# 15684                          Bernardin Tourism Project        1971-06-17
# 15694                               Highway Project (05)        1971-06-10
# 15695             Ibar Multipurpose Water Supply Project        1971-06-10
# 15835                               Highway Project (04)        1970-05-19
# 15879                         Telecommunications Project        1970-02-17
# 15885              Industrial Modernization Project (03)        1970-01-27
# 17836          0   35000000        0
# 17861          0   35000000        0
# 17903          0   30000000        0
# 17963          0   30000000        0
# 18175          0   30000000        0
# 18197          0   28000000        0
# 18228          0    2700000        0
#
#                                        borrower  \
# 11166             EPS                 ROA (ZEP)
# 11410              ALL SIX   ROAD ORGANIZATIONS
# 11479                                       NBY
# 11694  RTO BELGRADE; RE LJUBLJANA; RTO NOVI SAD
# 11695           RIZANA WW; ISTRIAN WW & PULA WW
# 11866                    LOCAL COMMERCIAL BANKS
# 12060    ROAD ORG. OF KOS;MAC;MON;VODJ;CRO    .
# 12225         LJUBLJANSKA BANKA LJUBLJANA (LBL)
# 12227         LJUBLJANSKA BANKA LJUBLJANA (LBL)
# 12375  ROADS ORGANIZATIONS & PARTICIPATING REP.
# 12577         INA NAFTAPLIN; NAFTA-GAS & P.B.S.
# 12617                  PRIVREDNA BANKA SARAJEVO
# 12671                                       NaN
# 12677                                       NaN
# 12809                                       NaN
# 13041                                       NaN
# 13046                                       NaN
# 13047                                       NaN
# 13053                                       NaN
# 13071                                       NaN
# 13098                                       NaN
# 13099                                       NaN
# 13231                                       NaN
# 13365                                       NaN
# 13402                                       NaN
# 13412                                       NaN
# 13526                                       NaN
# 13555                                       NaN
# 13629                                       NaN
# 13647                                       NaN
# ...                                         ...
# 15136                                       NaN
# 15182                                       NaN
# 15214                                       NaN
# 15238                                       NaN
# 15273                                       NaN
# 15274                                       NaN
# 15314                                       NaN
# 15388                                       NaN
# 15434                                       NaN
# 15563                                       NaN
# 15683                                       NaN
# 15684                                       NaN
# 15694                                       NaN
# 15695                                       NaN
# 15835                                       NaN
# 15879                                       NaN
# 15885                                       NaN
# 17467                                       NaN
# 17540                                       NaN
# 17576                                       NaN
# 17612                                       NaN
# 17638                                       NaN
# 17774                                       NaN
# 17836                                       NaN
# 17861                                       NaN
# 17903                                       NaN
# 17963                                       NaN
# 18175                                       NaN
# 18197                                       NaN
# 18228                                       NaN
#
#                                                impagency  \
# 11166                                                EPS
# 11410                                               FARP
# 11479                                                NBY
# 11694                                           BORROWER
# 11695                          BUTONIGA WW AND RIZANA WW
# 11866                                          BORROWERS
# 12060                                 ABOVE ORGANIZATION
# 12225                                          BORROWERS
# 12227                                          BORROWERS
# 12375     ROADS ORGANIZATIONS & PARTICIPATING REPUBLICS.
# 12577                        NAFTAPLIN; NAFTA-GAS & EXPL
# 12617  SELECTED FORESTRY; BOALS ASSOCIATED IN SIPAD &...
# 12671                                                NaN
# 12677                                                NaN
# 12809                                                NaN
# 13041                                                NaN
# 13046                                                NaN
# 13047                                                NaN
# 13053                                                NaN
# 13071                                                NaN
# 13098                                                NaN
# 13099                                                NaN
# 13231                                                NaN
# 13365                                                NaN
# 13402                                                NaN
# 13412                                                NaN
# 13526                                                NaN
# 13555                                                NaN
# 13629                                                NaN
# 13647                                                NaN
# ...                                                  ...
# 15136                                                NaN
# 15182                                                NaN
# 15214                                                NaN
# 15238                                                NaN
# 15273                                                NaN
# 15274                                                NaN
# 15314                                                NaN
# 15388                                                NaN
# 15434                                                NaN
# 15563                                                NaN
# 15683                                                NaN
# 15684                                                NaN
# 15694                                                NaN
# 15695                                                NaN
# 15835                                                NaN
# 15879                                                NaN
# 15885                                                NaN
# 17467                                                NaN
# 17540                                                NaN
# 17576                                                NaN
# 17612                                                NaN
# 17638                                                NaN
# 17774                                                NaN
# 17836                                                NaN
# 17861                                                NaN
# 17903                                                NaN
# 17963                                                NaN
# 18175                                                NaN
# 18197                                                NaN
# 18228                                                NaN
#
#                                                      url projectdoc   \
# 11166  http://projects.worldbank.org/P009285/kolubara...         NaN
# 11410  http://projects.worldbank.org/P009231/highway-...         NaN
# 11479  http://projects.worldbank.org/P009219/structur...         NaN
# 11694  http://projects.worldbank.org/P009225/railway-...         NaN
# 11695  http://projects.worldbank.org/P009275/istria-w...         NaN
# 11866  http://projects.worldbank.org/P009242/export-o...         NaN
# 12060  http://projects.worldbank.org/P009265/highway-...         NaN
# 12225  http://projects.worldbank.org/P009217/energy-c...         NaN
# 12227  http://projects.worldbank.org/P038996/indenerg...         NaN
# 12375  http://projects.worldbank.org/P009215/highway-...         NaN
# 12577  http://projects.worldbank.org/P009212/petroleu...         NaN
# 12617  http://projects.worldbank.org/P009211/bosnia-h...         NaN
# 12671  http://projects.worldbank.org/P009205/fertiliz...         NaN
# 12677  http://projects.worldbank.org/P009214/visegrad...         NaN
# 12809  http://projects.worldbank.org/P009210/monteneg...         NaN
# 13041  http://projects.worldbank.org/P009207/mostar-p...         NaN
# 13046  http://projects.worldbank.org/P009206/industri...         NaN
# 13047  http://projects.worldbank.org/P009208/power-tr...         NaN
# 13053  http://projects.worldbank.org/P009209/railway-...         NaN
# 13071  http://projects.worldbank.org/P009203/structur...         NaN
# 13098  http://projects.worldbank.org/P009201/kosovo-r...         NaN
# 13099  http://projects.worldbank.org/P009202/serbia-r...         NaN
# 13231  http://projects.worldbank.org/P009204/tuzla-re...         NaN
# 13365  http://projects.worldbank.org/P009198/semberij...         NaN
# 13402  http://projects.worldbank.org/P009197/bosnia-h...         NaN
# 13412  http://projects.worldbank.org/P009199/industri...         NaN
# 13526  http://projects.worldbank.org/P009200/kosovo-w...         NaN
# 13555  http://projects.worldbank.org/P009196/macedoni...         NaN
# 13629  http://projects.worldbank.org/P009193/kosovo-a...         NaN
# 13647  http://projects.worldbank.org/P009195/kosovo-r...         NaN
# ...                                                  ...         ...
# 15136  http://projects.worldbank.org/P009163/port-bar...         NaN
# 15182  http://projects.worldbank.org/P009164/railway-...         NaN
# 15214  http://projects.worldbank.org/P009156/industri...         NaN
# 15238  http://projects.worldbank.org/P009160/highway-...         NaN
# 15273  http://projects.worldbank.org/P009158/fob-iron...         NaN
# 15274  http://projects.worldbank.org/P009159/imt-trac...         NaN
# 15314  http://projects.worldbank.org/P009157/kikinda-...         NaN
# 15388  http://projects.worldbank.org/P009155/naftagas...         NaN
# 15434  http://projects.worldbank.org/P009154/agricult...         NaN
# 15563  http://projects.worldbank.org/P009153/power-tr...         NaN
# 15683  http://projects.worldbank.org/P009149/babin-ku...         NaN
# 15684  http://projects.worldbank.org/P009150/bernardi...         NaN
# 15694  http://projects.worldbank.org/P009151/highway-...         NaN
# 15273                  NaN                (Historic)Other industry!$!100!$!IY
# 15274                  NaN                (Historic)Other industry!$!100!$!IY
# 15314                  NaN                (Historic)Other industry!$!100!$!IY
# 15388                  NaN    (Historic)Oil and gas transportation!$!100!$!GP
# 15434                  NaN   (Historic)Agro-industry and marketing!$!100!$!AM
# 15563                  NaN  (Historic)Distribution and transmission!$!100!...
# 15683                  NaN       (Historic)Other urban development!$!100!$!UY
# 15684                  NaN       (Historic)Other urban development!$!100!$!UY
# 15694                  NaN                      (Historic)Highways!$!100!$!TH
# 15695                  NaN            (Historic)Urban water supply!$!100!$!WU
# 15835                  NaN                      (Historic)Highways!$!100!$!TH
# 15879                  NaN  (Historic)Telecommunications and informatics!$...
# 15885                  NaN  (Historic)Financial sector development!$!100!$!FS
# 17467                  NaN                      (Historic)Highways!$!100!$!TH
# 17540                  NaN  (Historic)Financial sector development!$!100!$!FS
# 17576                  NaN                                Railways!$!100!$!TW
# 17612                  NaN  (Historic)Financial sector development!$!100!$!FS
# 17638                  NaN                      (Historic)Highways!$!100!$!TH
# 17774                  NaN                                Railways!$!100!$!TW
# 17836                  NaN                                Railways!$!100!$!TW
# 17861                  NaN                      (Historic)Highways!$!100!$!TH
# 17903                  NaN                         (Historic)Hydro!$!100!$!PH
# 17963                  NaN                         (Historic)Hydro!$!100!$!PH
# 18175                  NaN           (Historic)Economic management!$!100!$!ME
# 18197                  NaN           (Historic)Economic management!$!100!$!ME
# 18228                  NaN                                Forestry!$!100!$!AT
#
#                                   sector2  \
# 11166  Renewable Energy Biomass!$!56!$!LB
# 11410                                 NaN
# 11479      Banking Institutions!$!36!$!FA
# 11694                                 NaN
# 11695                                 NaN
# 11866                                 NaN
# 12060                                 NaN
# 12225                                 NaN
# 12227                                 NaN
# 12375                                 NaN
# 12577                                 NaN
# 12617                                 NaN
# 12671                                 NaN
# 12677                                 NaN
# 12809                                 NaN
# 13041                                 NaN
# 13046                                 NaN
# 13047                                 NaN
# 13053                                 NaN
# 13071                                 NaN
# 13098                                 NaN
# 13099                                 NaN
# 13231                                 NaN
# 13365                                 NaN
# 13402                                 NaN
# 13412                                 NaN
# 13526                                 NaN
# 13555                                 NaN
# 13629                                 NaN
# 13647                                 NaN
# ...                                   ...
# 15136                                 NaN
# 15182                                 NaN
# 15214                                 NaN
# 15238                                 NaN
# 15273                                 NaN
# 15274                                 NaN
# 15314                                 NaN
# 15388                                 NaN
# 15434                                 NaN
# 15563                                 NaN
# 15683                                 NaN
# 15684                                 NaN
# 15694                                 NaN
# ...
# 11694                                  NaN    NaN
# 11695                                  NaN    NaN
# 11866                                  NaN    NaN
# 12060                                  NaN    NaN
# 12225                                  NaN    NaN
# 12227                                  NaN    NaN
# 12375                                  NaN    NaN
# 12577                                  NaN    NaN
# 12617                                  NaN    NaN
# 12671                                  NaN    NaN
# 12677                                  NaN    NaN
# 12809                                  NaN    NaN
# 13041                                  NaN    NaN
# 13046                                  NaN    NaN
# 13047                                  NaN    NaN
# 13053                                  NaN    NaN
# 13071                                  NaN    NaN
# 13098                                  NaN    NaN
# 13099                                  NaN    NaN
# 13231                                  NaN    NaN
# 13365                                  NaN    NaN
# 13402                                  NaN    NaN
# 13412                                  NaN    NaN
# 13526                                  NaN    NaN
# 13555                                  NaN    NaN
# 13629                                  NaN    NaN
# 13647                                  NaN    NaN
# ...                                    ...    ...
# 15136                                  NaN    NaN
# 15182                                  NaN    NaN
# 15214                                  NaN    NaN
# 15238                                  NaN    NaN
# 15273                                  NaN    NaN
# 15274                                  NaN    NaN
# 15314                                  NaN    NaN
# 15388                                  NaN    NaN
# 15434                                  NaN    NaN
# 15563                                  NaN    NaN
# 15683                                  NaN    NaN
# 15684                                  NaN    NaN
# 15694                                  NaN    NaN
# 15695                                  NaN    NaN
# 15835                                  NaN    NaN
# 15879                                  NaN    NaN
# 15885                                  NaN    NaN
# 17467                                  NaN    NaN
# 17540                                  NaN    NaN
# 17576                                  NaN    NaN
# 17612                                  NaN    NaN
# 17638                                  NaN    NaN
# 17774                                  NaN    NaN
# 17836                                  NaN    NaN
# 17861                                  NaN    NaN
# 17903                                  NaN    NaN
# 17963                                  NaN    NaN
# 18175                                  NaN    NaN
# 18197                                  NaN    NaN
# 18228                                  NaN    NaN
#
#                                                     goal financier  \
# 11166  Corporate Advocacy Priorities;Corporate Advoca...       NaN
# 11410  Global Public Goods Priorities|Corporate Advoc...       NaN
# 11479  Corporate Advocacy Priorities;Corporate Advoca...       NaN
# 11694                                                NaN       NaN
# 11695                                                NaN       NaN
# 11866                                                NaN       NaN
# 12060                                                NaN       NaN
# 12225                                                NaN       NaN
# 12227                                                NaN       NaN
# 12375                                                NaN       NaN
# 12577                                                NaN       NaN
# 12617                                                NaN       NaN
# 12671                                                NaN       NaN
# 12677                                                NaN       NaN
# 12809                                                NaN       NaN
# 13041                                                NaN       NaN
# 13046                                                NaN       NaN
# 13047                                                NaN       NaN
# 13053                                                NaN       NaN
# 13071                                                NaN       NaN
# 13098                                                NaN       NaN
# 13099                                                NaN       NaN
# 13231                                                NaN       NaN
# 13365                                                NaN       NaN
# 13402                                                NaN       NaN
# 13412                                                NaN       NaN
# 13526                                                NaN       NaN
# 13555                                                NaN       NaN
# 13629                                                NaN       NaN
# 13647                                                NaN       NaN
# ...                                                  ...       ...
# 15136                                                NaN       NaN
# 15182                                                NaN       NaN
# 15214                                                NaN       NaN
# 15238                                                NaN       NaN
# 15273                                                NaN       NaN
# 15274                                                NaN       NaN
# 15314                                                NaN       NaN
# 15388                                                NaN       NaN
# 15434                                                NaN       NaN
# 15563                                                NaN       NaN
# 15683                                                NaN       NaN
# 15684                                                NaN       NaN
# 15694                                                NaN       NaN
# 15695                                                NaN       NaN
# 15835                                                NaN       NaN
# 15879                                                NaN       NaN
# 15885                                                NaN       NaN
# 17467                                                NaN       NaN
# 17540                                                NaN       NaN
# 17576                                                NaN       NaN
# 17612                                                NaN       NaN
# 17638                                                NaN       NaN
# 17774                                                NaN       NaN
# 17836                                                NaN       NaN
# 17861                                                NaN       NaN
# 17903                                                NaN       NaN
# 17963                                                NaN       NaN
# 18175                                                NaN       NaN
# 18197                                                NaN       NaN
# 18228                                                NaN       NaN
# 17836      NaN      NaN        NaN      NaN       NaN     NaN
# 17861      NaN      NaN        NaN      NaN       NaN     NaN
# 17903      NaN      NaN        NaN      NaN       NaN     NaN
# 17963      NaN      NaN        NaN      NaN       NaN     NaN
# 18175      NaN      NaN        NaN      NaN       NaN     NaN
# 18197      NaN      NaN        NaN      NaN       NaN     NaN
# 18228      NaN      NaN        NaN      NaN       NaN     NaN
#
# [90 rows x 56 columns]

# %% [markdown]
# Yugoslavia officially ended on [April 27th, 1992](https://en.wikipedia.org/wiki/Yugoslavia).
#
# In the code cell below, filter for projects with a 'boardapprovaldate' prior to April 27th, 1992 **and** with 'countryname' Bosnia and Herzegovina, Croatia, Kosovo, Macedonia, Serbia **or** Slovenia. You'll see there are a total of 12 projects in the data set that match this criteria. Save the results in the republics variable

# %%
import datetime

# TODO: filter the projects data set for project boardapprovaldate prior to April 27th, 1992 AND with countryname
#  of either 'Bosnia and Herzegovina', 'Croatia', 'Kosovo', 'Macedonia', 'Serbia', or 'Sovenia'. Store the
#  results in the republics variable
#
#  TODO: so that it's easier to see all the data, keep only these columns:

projects = projects[['regionname', 'countryname', 'lendinginstr', 'totalamt', 'boardapprovaldate',
'location','GeoLocID', 'GeoLocName', 'Latitude','Longitude','Country', 'project_name']]

# TODO: sort the results by boardapprovaldate

newyugo = ['Bosnia', 'Croatia', 'Kosovo', 'Macedonia', 'Serbia', 'Montenegro', 'Sovenia']

projects['boardapprovaldate'] = pd.to_datetime(projects['boardapprovaldate'])

republics = projects.loc[(projects['boardapprovaldate']<='1992-04-27') & (projects['countryname'].str.contains('|'.join(newyugo)))]

# # show the results
republics
# Out:
#                     regionname             countryname  \
# 11696  Europe and Central Asia     Republic of Croatia
# 12061  Europe and Central Asia     Republic of Croatia
# 12062  Europe and Central Asia     Republic of Croatia
# 12063  Europe and Central Asia  Bosnia and Herzegovina
# 12228  Europe and Central Asia     Republic of Croatia
# 13048  Europe and Central Asia  Bosnia and Herzegovina
# 13049  Europe and Central Asia     Republic of Croatia
# 13050  Europe and Central Asia               Macedonia
# 13973  Europe and Central Asia               Macedonia
#
#                                  lendinginstr  totalamt boardapprovaldate  \
# 11696                Specific Investment Loan  28000000        1989-05-23
# 12061  Sector Investment and Maintenance Loan         0        1987-10-13
# 12062  Sector Investment and Maintenance Loan         0        1987-10-13
# 12063  Sector Investment and Maintenance Loan         0        1987-10-13
# 12228             Financial Intermediary Loan         0        1987-03-31
# 13048                Specific Investment Loan         0        1983-07-26
# 13049                Specific Investment Loan         0        1983-07-26
# 13050                Specific Investment Loan         0        1983-07-26
# 13973                Specific Investment Loan  24000000        1980-02-01
#
#       location GeoLocID GeoLocName Latitude Longitude Country  \
# 11696      NaN      NaN        NaN      NaN       NaN     NaN
# 12061      NaN      NaN        NaN      NaN       NaN     NaN
# 12062      NaN      NaN        NaN      NaN       NaN     NaN
# 12063      NaN      NaN        NaN      NaN       NaN     NaN
# 12228      NaN      NaN        NaN      NaN       NaN     NaN
# 13048      NaN      NaN        NaN      NaN       NaN     NaN
# 13049      NaN      NaN        NaN      NaN       NaN     NaN
# 13050      NaN      NaN        NaN      NaN       NaN     NaN
# 13973      NaN      NaN        NaN      NaN       NaN     NaN
#
#                                            project_name
# 11696            Istria Water Supply & Sewerage Project
# 12061                                 HIGHWAY SECTOR II
# 12062                                 HIGHWAY SECTOR II
# 12063                                 HIGHWAY SECTOR II
# 12228                               IND.ENERGY EFFIC. I
# 13048                                   POWER TRANS.III
# 13049                                   POWER TRANS.III
# 13050                                   POWER TRANS.III
# 13973  Agriculture & Agroindustry 2 Project (Macedonia)

# %% [markdown]
# Are these projects also represented in the data labeled Yugoslavia? In the code cell below, filter for Yugoslavia projects approved between February 1st, 1980 and May 23rd, 1989 which are the minimum and maximum dates in the results above. Store the results in the yugoslavia variable.
#
# The goal is to see if there are any projects represented more than once in the data set.

# %%
# TODO: Filter the projects data for Yugoslavia projects between
# February 1st, 1980 and May 23rd, 1989. Store the results in the
# Yugoslavia variable. Keep the same columns as the previous code cell.
# Sort the values by boardapprovaldate

yugoslavia = projects.loc[
    (projects['countryname'].str.contains('Yugoslavia')) &
    (projects['boardapprovaldate']>='1980-2-1') & 
    (projects['boardapprovaldate']<='1989-05-23')]

# show the results
yugoslavia
# Out:
#                     regionname                               countryname  \
# 11694  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 11695  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 11866  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12060  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12225  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12227  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12375  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12577  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12617  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12671  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12677  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 12809  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13041  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13046  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13047  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13053  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13071  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13098  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13099  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13231  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13365  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13402  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13412  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13526  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13555  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13629  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13647  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13706  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13773  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13937  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13966  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
#
#                                  lendinginstr   totalamt boardapprovaldate  \
# 11694  Sector Investment and Maintenance Loan  138000000        1989-05-23
# 11695                Specific Investment Loan   60000000        1989-05-23
# 11866             Financial Intermediary Loan  120000000        1988-06-29
# 12060  Sector Investment and Maintenance Loan   68000000        1987-10-13
# 12225             Financial Intermediary Loan   90000000        1987-03-31
# 12227             Financial Intermediary Loan          0        1987-03-31
# 12375  Sector Investment and Maintenance Loan  121500000        1986-06-10
# 12577                Specific Investment Loan   92500000        1985-06-27
# 12617                Specific Investment Loan   35000000        1985-06-06
# 12671                  Sector Adjustment Loan   90000000        1985-05-03
# 12677                Specific Investment Loan  125000000        1985-04-30
# 12809             Financial Intermediary Loan   40000000        1984-07-31
# 13041                Specific Investment Loan   61000000        1983-08-02
# 13046             Financial Intermediary Loan   70000000        1983-07-26
# 13047                Specific Investment Loan  120000000        1983-07-26
# 13053  Sector Investment and Maintenance Loan  110000000        1983-07-19
# 13071              Structural Adjustment Loan  275000000        1983-06-28
# 13098             Financial Intermediary Loan   79000000        1983-06-09
# 13099             Financial Intermediary Loan  136000000        1983-06-09
# 13231                Specific Investment Loan   30000000        1983-01-25
# 13365                Specific Investment Loan   34600000        1982-05-27
# 13402                Specific Investment Loan   35000000        1982-05-04
# 13412             Financial Intermediary Loan   66000000        1982-04-27
# 13526                Specific Investment Loan   41000000        1981-11-10
# 13555             Financial Intermediary Loan   80000000        1981-07-14
# 13629             Financial Intermediary Loan   90000000        1981-05-14
# 13647                Specific Investment Loan   34000000        1981-04-28
# 13706             Financial Intermediary Loan   87000000        1981-03-03
# 13773             Financial Intermediary Loan  110000000        1980-10-28
# 13937                Specific Investment Loan  125000000        1980-03-25
# 13966             Financial Intermediary Loan   86000000        1980-02-26
#
#       location GeoLocID GeoLocName Latitude Longitude Country  \
# 11694      NaN      NaN        NaN      NaN       NaN     NaN
# 11695      NaN      NaN        NaN      NaN       NaN     NaN
# 11866      NaN      NaN        NaN      NaN       NaN     NaN
# 12060      NaN      NaN        NaN      NaN       NaN     NaN
# 12225      NaN      NaN        NaN      NaN       NaN     NaN
# 12227      NaN      NaN        NaN      NaN       NaN     NaN
# 12375      NaN      NaN        NaN      NaN       NaN     NaN
# 12577      NaN      NaN        NaN      NaN       NaN     NaN
# 12617      NaN      NaN        NaN      NaN       NaN     NaN
# 12671      NaN      NaN        NaN      NaN       NaN     NaN
# 12677      NaN      NaN        NaN      NaN       NaN     NaN
# 12809      NaN      NaN        NaN      NaN       NaN     NaN
# 13041      NaN      NaN        NaN      NaN       NaN     NaN
# 13046      NaN      NaN        NaN      NaN       NaN     NaN
# 13047      NaN      NaN        NaN      NaN       NaN     NaN
# 13053      NaN      NaN        NaN      NaN       NaN     NaN
# 13071      NaN      NaN        NaN      NaN       NaN     NaN
# 13098      NaN      NaN        NaN      NaN       NaN     NaN
# 13099      NaN      NaN        NaN      NaN       NaN     NaN
# 13231      NaN      NaN        NaN      NaN       NaN     NaN
# 13365      NaN      NaN        NaN      NaN       NaN     NaN
# 13402      NaN      NaN        NaN      NaN       NaN     NaN
# 13412      NaN      NaN        NaN      NaN       NaN     NaN
# 13526      NaN      NaN        NaN      NaN       NaN     NaN
# 13555      NaN      NaN        NaN      NaN       NaN     NaN
# 13629      NaN      NaN        NaN      NaN       NaN     NaN
# 13647      NaN      NaN        NaN      NaN       NaN     NaN
# 13706      NaN      NaN        NaN      NaN       NaN     NaN
# 13773      NaN      NaN        NaN      NaN       NaN     NaN
# 13937      NaN      NaN        NaN      NaN       NaN     NaN
# 13966      NaN      NaN        NaN      NaN       NaN     NaN
#
#                                             project_name
# 11694                               Railway Project (07)
# 11695             Istria Water Supply & Sewerage Project
# 11866                 Export Oriented Industries Project
# 12060                        Highway Sector Project (02)
# 12225         Energy Conservation & Substitution Project
# 12227                                IND.ENERGY EFFIC. I
# 12375                             Highway Sector Project
# 12577                           Petroleum Sector Project
# 12617                Bosnia Herzegovina Forestry Project
# 12671                     Fertilizer Sector Loan Project
# 12677                     Visegrad Hydroelectric Project
# 12809            Montenegro Regional Development Project
# 13041                                  MOSTAR POWER(SAP)
# 13046                     Industrial Credit Project (07)
# 13047  Power Transmission Project (03) Energy Managem...
# 13053                               Railway Project (06)
# 13071            Structural Adjustment Loan Project (01)
# 13098                Kosovo Regional Development Project
# 13099                Serbia Regional Development Project
# 13231    Tuzla Region Water Supply & Environment Project
# 13365                         Semberija Drainage Project
# 13402  Bosnia Herzegovina Agriculture Development Pro...
# 13412                     Industrial Credit Project (06)
# 13526                        Kosovo Water Supply Project
# 13555     Macedonia Agriculture Development Project (03)
# 13629             Kosovo Agriculture Development Project
# 13647                             Kosovo Railway Project
# 13706           Morava Regional Development Project (02)
# 13773                     Industrial Credit Project (05)
# 13937                               Highway Project (11)
# 13966                    Agriculture Credit Project (03)

# %% [markdown]
# And as a final step, try to see if there are any projects in the republics variable and yugoslavia variable that could be the same project.
#
# There are multiple ways to do that. As a suggestion, find unique dates in the republics variable. Then separately find unique dates in the yugoslavia variable. Concatenate (ie append) the results together. And then count the number of times each date occurs in this list. If a date occurs twice, that means the same boardapprovaldate appeared in both the Yugoslavia data as well as in the republics data.
#
# You should find that there are four suspicious cases:
#
# * July 26th, 1983
# * March 31st, 1987
# * October 13th, 1987
# * May 23rd, 1989

# %%
republics['boardapprovaldate'].unique()
# Out:
# array(['1989-05-23T00:00:00.000000000', '1987-10-13T00:00:00.000000000',
#        '1987-03-31T00:00:00.000000000', '1983-07-26T00:00:00.000000000',
#        '1980-02-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
import numpy as np

# TODO: find the unique dates in the republics variable
republic_unique_dates = republics['boardapprovaldate'].unique()

# TODO: find the unique dates in the yugoslavia variable
yugoslavia_unique_dates = yugoslavia['boardapprovaldate'].unique()

# TODO: make a list of the results appending one list to the other
dates = np.concatenate((republic_unique_dates, yugoslavia_unique_dates))

# TODO: print out the dates that appeared twice in the results
u, c = np.unique(dates, return_counts=True)
dup = u[c > 1]
print(dup)
# Out:
# ['1983-07-26T00:00:00.000000000' '1987-03-31T00:00:00.000000000'
#  '1987-10-13T00:00:00.000000000' '1989-05-23T00:00:00.000000000']

# %% [markdown]
# # Conclusion
#
# On July 26th, 1983, for example, projects were approved for Bosnia and Herzegovina, Croatia, Macedonia, Slovenia, and Yugoslavia. The code below shows the projects for that date. You'll notice that Yugoslavia had two projects, one of which was called "Power Transmission Project (03) Energy Managem...". The projects in the other countries were all called "POWER TRANS.III".
#
# This looks like a case of duplicate data. What you end up doing with this knowledge would depend on the context. For example, if you wanted to get a true count for the total number of projects in the data set, should all of these projects be counted as one project?
#
# Run the code cell below to see the projects in question.

# %%
import datetime

# run this code cell to see the duplicate data
pd.concat([yugoslavia[yugoslavia['boardapprovaldate'] == datetime.date(1983, 7, 26)], republics[republics['boardapprovaldate'] == datetime.date(1983, 7, 26)]])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   after removing the cwd from sys.path.
#                     regionname                               countryname  \
# 13046  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13047  Europe and Central Asia  Socialist Federal Republic of Yugoslavia
# 13048  Europe and Central Asia                    Bosnia and Herzegovina
# 13049  Europe and Central Asia                       Republic of Croatia
# 13050  Europe and Central Asia                                 Macedonia
#
#                       lendinginstr   totalamt boardapprovaldate location  \
# 13046  Financial Intermediary Loan   70000000        1983-07-26      NaN
# 13047     Specific Investment Loan  120000000        1983-07-26      NaN
# 13048     Specific Investment Loan          0        1983-07-26      NaN
# 13049     Specific Investment Loan          0        1983-07-26      NaN
# 13050     Specific Investment Loan          0        1983-07-26      NaN
#
#       GeoLocID GeoLocName Latitude Longitude Country  \
# 13046      NaN        NaN      NaN       NaN     NaN
# 13047      NaN        NaN      NaN       NaN     NaN
# 13048      NaN        NaN      NaN       NaN     NaN
# 13049      NaN        NaN      NaN       NaN     NaN
# 13050      NaN        NaN      NaN       NaN     NaN
#
#                                             project_name
# 13046                     Industrial Credit Project (07)
# 13047  Power Transmission Project (03) Energy Managem...
# 13048                                    POWER TRANS.III
# 13049                                    POWER TRANS.III
# 13050                                    POWER TRANS.III
